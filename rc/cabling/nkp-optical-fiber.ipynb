# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-infrastructure/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Optical Fiber``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Optical Fiber](#infrastructure)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="infrastructure"></a>
# ***
# ### Optical Fiber
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Fiber Communications
# ***

# %% [markdown]
# Communication over optic fiber is communicating using wavelengths of light.

# %% [markdown]
# This is very different than communicating using copper cables where an electrical signal will create radio frequency interference that could be heard from outside of that cable.

# %% [markdown]
# With a fiber optic communication, there is no radio frequency (RF) or any type of signal that can be tapped from the outside.

# %% [markdown]
# Copper cables also communicate over hundreds of meters of distance, whereas something sent over optic fiber can communicate over kilometers of distance. And

# %% [markdown]
# Since it’s just light that’s going through these optic fibers, any external interference with radio frequencies will have no impact on the light that’s going through optic fiber.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here’s an image of optic fiber and the connectors that you would have on the end of it.

# %% [markdown]
# Can see that it is very narrow strands of optic fiber that are sent from one end to the other and usually there’s a larger coating around the outside to help protect it.

# %% [markdown]
# At the end of the optic fiber where we’re plugging into our networking equipment, there’s often ceramic ferrule around the end to help protect this very delicate fiber optic that’s on the inside.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here’s a cross-section of some optic fiber.

# %% [markdown]
# The core is where we will send that light from one end of the fiber to the other.

# %% [markdown]
# Around the core is a cladding, and the cladding has a lower index of refraction, which means the light is going to reflect off of the cladding and stay inside the core.

# %% [markdown]
# To protect all of this, a coating is added around the outside of both the core and the cladding.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### SC Connector
# ***

# %% [markdown]
# Close up picture of the end of an SC connector.

# %% [markdown]
# This is the connector that will be plugging into your networking equipment.

# %% [markdown]
# Fiber core is this very small dot that’s right in the middle, it’s almost difficult to see in this picture.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# That core is protected with a ceramic ferrule around the outside - this allows you to connect and disconnect this fiber from your networking equipment without damaging the fiber that’s on the inside.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Multi-mode Fiber
# ***

# %% [markdown]
# When you start working in fiber optics, you’ll generally work with multi-mode fiber or single mode fiber.

# %% [markdown]
# Multi fiber is commonly used for relatively short range communication. In the world of fiber optics, that’s usually two kilometers or less in length.

# %% [markdown]
# The type of light that’s being used to send the signal through the fiber is usually something that’s also relatively inexpensive, something like an LCD.

# %% [markdown]
# We call this multi-mode fiber, because the core of the fiber is larger than the wavelength of the light that we’re sending through the fiber.

# %% [markdown]
# As the signal propagates down the fiber, it will begin to disperse and you will have multiple modes of signal arrive at the other end.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Single-mode Fiber
# ***

# %% [markdown]
# Single mode fiber is commonly used for much longer distances.

# %% [markdown]
# With some single mode fiber configurations, you can go up to 100 kilometers without having to reprocess that signal.

# %% [markdown]
# However, this comes at a financial cost, because we’re using much more expensive light sources to be able to send that all the way down the single mode fiber.

# %% [markdown]
# The core of the single mode fiber is much narrower than the multi-node fiber allowing us to send that single mode from one end to the other.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Controlling Light
# ***

# %% [markdown]
# The physics of dealing with optic fiber are very different than the physics we had with copper cables.

# %% [markdown]
# We have to worry about light that we’re sending out.

# %% [markdown]
# We also have to worry about the light that may be reflected back to the original source.

# %% [markdown]
# There are two different kinds of connectors that can help us control this reflected light.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Ultra-polished Connector - UPC
# ***

# %% [markdown]
# One of these is a UPC connector.

# %% [markdown]
# That stands for ultra polished connectors, and there is a zero degree angle between the end of the ferrule and the device that we’re plugging into.

# %% [markdown]
# There’s usually a very high return loss when you’re using a UPC or ultra polished connector.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Angle-polished Connector - APC
# ***

# %% [markdown]
# The other type of connector you may see is an APC.

# %% [markdown]
# This is an angle polished connector where the ferrules connect to each other at a slight angle, and so the reflection is a little bit different when you’re using an APC.

# %% [markdown]
# There will commonly be a lower amount of light returned to the source, but you’re also losing a little bit more light on the connector itself.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### UPC Versus APC
# ***

# %% [markdown]
# Here’s what two UPC connectors look like if you were to push them onto each other.

# %% [markdown]
# You can see there is a zero degree angle difference between these two ends of that UPC. And you can see as we’re sending signal down this connection, there will be reflections that come back from this zero degree angle connector.

# %% [markdown]
# This is very similar to taking a flashlight and shining it through a window. If you’re directly in front of that window, some of that light will be reflected back to you and make it difficult for you to see.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# One way to avoid that is to stand at an angle to the window, and that’s effectively what we do with an APC or angle polish connector.

# %% [markdown]
# You can see there is an 80 degree difference here in these connectors, so as this light passes through, it will be reflected off at an angle rather than being reflected directly back to the source.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
