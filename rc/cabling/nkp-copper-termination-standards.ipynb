# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-infrastructure/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Copper Termination Standards``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Copper Termination Standards](#infrastructure)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="infrastructure"></a>
# ***
# ### Copper Termination Standards
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wiring Standards
# ***

# %% [markdown]
# The type of copper cables you use on your network is important.

# %% [markdown]
# But also the termination of those cables is important. That’s why before implementing a new network, it’s always good to grab a cable tester and make sure that all of your cables have been terminated correctly.

# %% [markdown]
# These cable testers are relatively inexpensive and they can quickly show you exactly the way the cable is mapped from one end of the connector to the other end.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### T568A and T568B Termination
# ***

# %% [markdown]
# Like most things in networking, there is a standard for terminating cables.

# %% [markdown]
# The EIA/TIA-568-B standard pin assignments shows you exactly how to terminate eight conductor 100-ohm balanced twisted pair cabling, which is exactly the cabling we use on today’s networks.

# %% [markdown]
# You have the choice of two different standards when you’re terminating copper cables.

# %% [markdown]
# One is the T568A and the other is the T568B.

# %% [markdown]
# These are two different termination standards.

# %% [markdown]
# So you would usually pick the one that you’d like to use and stay with that termination standard throughout the installation of your cables.

# %% [markdown]
# Some people will use certain types of pin outs depending on how they’re running these cables. For example, if you’re running cables on a single floor, some people prefer to use T568A as the pin out for all your horizontal cabling.

# %% [markdown]
# But some organizations prefer using 568B.

# %% [markdown]
# It really doesn’t matter which one you use, as long as you stay consistent.

# %% [markdown]
# You do not want to terminate one end of the cable with 568A and the other end with 568B. You will run into problems, especially on a gigabit network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### T568A and T568B Termination - RJ-45 Connector Pins
# ***

# %% [markdown]
# If we were to look at all of the different pins inside of an RJ-45 connector, and if we look at this from the bottom of the connector, those pins are numbered 1 through 8.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Each one of these standards uses slightly different pin outs.

# %% [markdown]
# You can see on the 568A standard, pin one is white and green and pin two is green.

# %% [markdown]
# You can see in the 568B standard, it’s white and orange, and orange for pins one and two.

# %% [markdown]
# So notice the green and the orange are different between the 568A and the 568B.

# %% [markdown]
# Fortunately, pins four and five, which are blue and white and blue and pins seven and eight, which are white and brown and brown, are identical between 568A and 568B.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You should be able to look at the bottom of an RJ-45 connector and see exactly how it happens to be terminated.

# %% [markdown]
# You can see we’ve got white, orange, orange, white, green, a blue, a white blue, a green, a white brown, and a brown.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So this would be a 568B termination. And on the other end of a straight through cable, we want to be sure that we’re also terminating it with 568B.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Straight-through Cables
# ***

# %% [markdown]
# If we’re connecting a workstation to a switch, then we’re usually using a straight-through cable.

# %% [markdown]
# This is where pin one is connected to pin one. Pin two is connected to pin two, pin three to pin three, and so on, all the way through pin eight.

# %% [markdown]
# This is also called a patch cable and it’s one of the most common ethernet cables you run into.

# %% [markdown]
# If you have ethernet cables connecting your equipment and you disconnect those and look at the ends, you’ll see that all of the pins are connecting straight through from one side to the other.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Straight-through Cables - 10BASE-T - 100BASE-T
# ***

# %% [markdown]
# If we need a straight-through cable for 10BASE-T, which is a 10 megabit ethernet network, or a 100BASE-T, which a hundred megabit ethernet network, this straight-through cable only needs two pairs.

# %% [markdown]
# So there’s four wires inside of the cable that are used for these specific ethernet standards.

# %% [markdown]
# You can see pins one and two on a network interface card are your transmit pairs and if you’re looking at a network switch, pins one and two are the receive pairs.

# %% [markdown]
# We are running straight through from transmit to receive for those two devices.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Straight-through Cables - 1000BASE-T
# ***

# %% [markdown]
# The straight through cable is a little different when you look at gigabit ethernet, which has 1000BASE-T.

# %% [markdown]
# This straight through cable is going to use all four pairs inside of the cable.

# %% [markdown]
# Also notice there’s no dedicated transmit and receive pairs.

# %% [markdown]
# Instead, you’re able to both send and receive traffic through a 1000BASE-T connection on the same wires at the same time.

# %% [markdown]
# This is a lot different than dedicating a transmit and receive and instead, we’re able to send traffic in both directions simultaneously.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Ethernet Cross-over Cables
# ***

# %% [markdown]
# If you need to connect like devices to each other, you would not use a straight-through cable.

# %% [markdown]
# In those cases, you’d use a cross-over cable - so if you’re connecting a workstation to a workstation, you need a crossover - if you’re connecting a switch to a switch, you need a cross-over cable.

# %% [markdown]
# You can see the pin outs on a cross-over cable are a lot different than a straight-through.

# %% [markdown]
# No longer going from pin one to pin one - going from pin one to pin three, and pin two to pin six, and so on.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If you are connecting like equipment to each other, you may find that you don’t need to perform the cross-over inside of the cable.

# %% [markdown]
# Instead, you can perform the cross-over inside of the device that you happen to be using - this is called auto-MDI-X.

# %% [markdown]
# This is something very common on the ethernet cards inside of your workstations, your servers, your routers, and all other ethernet devices.

# %% [markdown]
# The device will examine the incoming signal and make a determination on whether it should act as a straight-through signal or as a cross-over, and will make that change in the ethernet card itself.

# %% [markdown]
# One thing you’ll notice with this crossover cable is that one side of this is not 568A and the other side of this 568B.

# %% [markdown]
# Ethernet crossover does not deal with 568B or 568A standards.

# %% [markdown]
# The ethernet crossover is something very specific to the way ethernet connects to each other and it’s not related to a termination standard.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Ethernet Cross-over Cables - 10BASE-T - 100BASE-T
# ***

# %% [markdown]
# Visually, for a 10 megabit and 100 megabit ethernet where we’re using two pair, this is the way the cross-over cable would look.

# %% [markdown]
# Going from pin one to pin three and pin two to pin six.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Ethernet Cross-over Cables - 1000BASE-T
# ***

# %% [markdown]
# Looking at an ethernet crossover cable for 1000BASE-T, or gigabit ethernet, you can see that we maintain the pin one to pin three and pin two to pin six so that we have backwards compatibility.

# %% [markdown]
# But you can see we’re also crossing over pins four and five and pins seven and eight.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
