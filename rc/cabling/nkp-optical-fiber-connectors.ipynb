# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-infrastructure/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Optical Fiber Connectors``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Optical Fiber Connectors](#infrastructure)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="infrastructure"></a>
# ***
# ### Optical Fiber Connectors
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Straight Tip (ST) Connector
# ***

# %% [markdown]
# The ST connector is the straight tip connector.

# %% [markdown]
# Can see by the connector itself, that it has a bayonet connector.

# %% [markdown]
# You would push it in and twist it to lock it in, and then you would need to untwist and then pull to be able to release it.

# %% [markdown]
# It has a rounded connector at the end, and you can see there’s a relatively long ferrule that’s sticking out, which makes it very easy to spot an ST connector.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### SC Connector
# ***

# %% [markdown]
# The connector is commonly referred to as a subscriber connector, a standard connector or visually you can see it as a square connector.

# %% [markdown]
# The square connector on these ends is very different than the rounded connector that was on the ST connector.

# %% [markdown]
# They’ve also got these plastic keys on these sections of the square so that you’re plugging it in in exactly the right way to the networking equipment.

# %% [markdown]
# You still have a round ferrule in the middle that contains your fiber optic and these push into a connection, and then pull out, which is very different than the bayonet that we saw with the ST connector.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### LC Connector
# ***

# %% [markdown]
# As we progress through these connector type, you’ll notice they’re getting smaller and smaller.

# %% [markdown]
# That’s because the manufacturers would like to put as many interfaces as possible in their networking equipment, and a smaller fiber connector means that they can put more interfaces on a single card.

# %% [markdown]
# One of these smaller types of interfaces is the LC connector that stands for Lucent connector - it can be referred to as the local connector, and some people refer to it as the little connector.

# %% [markdown]
# With the LC connector, both sides of the fiber, the transmit and the receive are molded into the same connector itself, and there’s a locking mechanism on the top very similar to an RJ-45 connector you might find with a copper connection.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Of course, these can also be used as individual fibers, and you’ll notice that the size is a bit smaller than the ST and the SC connectors.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### MT-RJ Connector
# ***

# %% [markdown]
# This stands for mechanical transfer register jack.

# %% [markdown]
# Some may say it refers to media termination recommended jack - it’s the smallest connector that we’ve seen so far.

# %% [markdown]
# Able to fit the transmit and receive fibers into a form factor that is about the same size as an RJ-45 copper connector.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
