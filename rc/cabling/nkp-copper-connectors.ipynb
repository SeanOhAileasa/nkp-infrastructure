# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-infrastructure/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Copper Connectors``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Copper Connectors](#infrastructure)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="infrastructure"></a>
# ***
# ### Copper Connectors
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### RJ-11
# ***

# %% [markdown]
# If you’re connecting up a traditional phone line or you’re using a modem connection over a traditional phone line, then you’re probably using an RJ-11 connector.

# %% [markdown]
# This is what we call a six position, two conductor cable or a 6P2C connector.

# %% [markdown]
# You can see there are six different types of positions that can be on these cables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But if you look into a modem, you’ll see that only two conductors are in use.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If you’re connecting a telephone or a modem to a traditional public switch telephone network, a PSTN, or the plain old telephone system or POTS, then you’re probably very familiar with the RJ-11 connector.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### RJ-14
# ***

# %% [markdown]
# If this is an RJ-14 cable, that means that it may be using dual lines and it may fill in two more of these wires to be a six position, four conductor cable (6P4C).

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### RJ-45
# ***

# %% [markdown]
# We use a modular connector that’s a little bit larger for Ethernet.

# %% [markdown]
# It is an RJ-45 connector. The RJ stands for registered jack. This is an eight position, eight conductor cable (8P8C), and we do use all eight of those conductors for our gigabit Ethernet.

# %% [markdown]
# You can see all eight of those conductors are in use, and if you’re connecting an Ethernet network over copper then you’re using an RJ-45 connector.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### BNC Connector
# ***

# %% [markdown]
# A bayonet connector is one that you push in and twist to be able to lock into place.

# %% [markdown]
# And a common bayonet connector used for networking is the BNC connector.

# %% [markdown]
# It stands for Bayonet Neill-Concelman. It’s created by Paul Neill at Bell Labs and Carl Concelman at Amphenol.

# %% [markdown]
# And we commonly see this used on WAN connections like DS3.

# %% [markdown]
# We’ll bring in the coax cable and connect it up through that bayonet connection. These are coax cables, so they can be relatively rigid and bulky to work with and if you’re plugging in a lot of DS3 networks, then you’ll have a lot of BNC connectors on your patch panel.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### DB-9 and DB-25 Connector
# ***

# %% [markdown]
# Another common copper connector is the DB-9 connector.

# %% [markdown]
# The D in DB-9 stands for D-subminiature or D-sub.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Specifies this type of connector that looks like a D. There are different sizes from DA through DE. You’ll see the DB-25 listed, and the DE-9 is listed.

# %% [markdown]
# The DB-25 was one of the most popular serial connector types early on in computing and when the nine-pin version of this was released, started calling it the DB-9 even though technically it’s a DE-9.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These are commonly used for what we call an RS-232 serial connection and early on in our computers, we used these for almost everything, modems, printers, mice, networks, and anything else that we needed to be able to send some type of signal over.

# %% [markdown]
# These days, we don’t commonly see the 25-pin connection in use, it’s most often the nine-pin connector, and it’s often used as a console connection for a router, a switch, or some other type of infrastructure device.

# %% [markdown]
# Here’s a back of an older motherboard that has a DB-25 connector used for printing, there’s a DB-9 serial connection, and that’s what we would connect our cable to so that we can access a router or switch at the command line.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### F-connector
# ***

# %% [markdown]
# If you’ve connected cable television or cable Internet modem, you’ve probably brought it in through coax with this F-connector at the end of the cable.

# %% [markdown]
# It’s usually brought in on something like an RG-6 cable for this coax connection, and it uses this threaded connector.

# %% [markdown]
# Once you twist it on to the connector, it’s not coming off of that connection unless you completely untwist this F-connector.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
