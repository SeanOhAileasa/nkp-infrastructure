# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-infrastructure/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Transceivers``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Network Transceivers](#infrastructure)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="infrastructure"></a>
# ***
# ### Network Transceivers
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transceiver
# ***

# %% [markdown]
# A transceiver is a device that is both a transmitter and a receiver, and usually it’s in a single device.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is commonly used in networking as a modular network interface - for example, you can see on this switch, have interfaces that are in copper for these two RJ-45s.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But you also have the option to plug-in a transceiver that can be used for additional interfaces on the switch.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This would allow you to connect this switch with fiber connections, and they could be single-mode fiber or multi-mode fiber, but you can choose exactly the type of interface you need using these transceivers.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Duplex Communication
# ***

# %% [markdown]
# A traditional transceiver provides us with duplex communication, because there are two interfaces for two fibers on this particular transceiver.

# %% [markdown]
# One of these connectors might be for transmit, and the other fiber coming in would be for receive.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bi-directional (BiDi) Transceivers
# ***

# %% [markdown]
# Fiber is relatively expensive to run, and of course, we have a limited number of interfaces on our networking equipment.

# %% [markdown]
# That’s why some of your networking equipment may be able to support bi-directional transceivers or BiDi transceivers.

# %% [markdown]
# These bidirectional transceivers allow you to transmit and receive over a single strand of fiber.

# %% [markdown]
# So this effectively doubles the amount of use that you have for the fibers in your infrastructure.

# %% [markdown]
# It’s using two different wavelengths to complete this, so you don’t have to run twice as much fiber - instead you can use a bidirectional transceiver.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Gigabit Interface Converter (GBIC)
# ***

# %% [markdown]
# One of the earlier transceiver standards was created for gigabit networks, and this was the GBIC or the Gigabit Interface Converter.

# %% [markdown]
# You can see the GBIC is right here next to this USB key, and it usually is connected with something like an SC connector on to the GBIC itself.

# %% [markdown]
# These are commonly used on gigabit networks and fiber channel networks, but they are relatively large compared to some of the newer styles of transceivers.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here’s a GBIC that’s being used with SC connectors in this gigabit Ethernet switch.

# %% [markdown]
# You can simply slide the GBIC into an open slot, connect your fiber, and now you’ve got a fiber connection using this modular transceiver.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Small Form-factor Pluggable - SFP
# ***

# %% [markdown]
# Manufacturers soon found that they could perform similar functions using a much smaller transceiver, and this was the SFP or the small form factor pluggable.

# %% [markdown]
# The SFP you can see is a lot smaller than the older style GBIC.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These are commonly used for one gig fiber connections. They’re also one gig copper connections that you can get instead of having a fiber connector at the end of this.

# %% [markdown]
# We commonly associate transceivers with fiber connections, but you can also get transceivers that have RJ-45 copper connectors on there as well.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Enhanced Small Form-factor Pluggable - SFP+
# ***

# %% [markdown]
# As our technology’s move towards 10 gig networking, we improve the technology by creating the enhanced small form factor pluggable or SFP+.

# %% [markdown]
# It looks and has exactly the same form factor as the older style SFP, but you’re able to support much higher data rates through these newer style transceivers.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Quad Small Form-factor Pluggable - QSFP
# ***

# %% [markdown]
# For very high speed networking, you may want to look into using a QSFP or quad small form-factor pluggable.

# %% [markdown]
# These effectively are four SFPs put into a single transceiver.

# %% [markdown]
# That means a four-channel SFP can support x4 1 Gbit/sec connections (4 Gbit/sec).

# %% [markdown]
# For higher speeds we could use a SFP for four-channel SFP plus.

# %% [markdown]
# This would be four 10 Gbit/sec connections or 40 Gbit/sec through a single transceiver.

# %% [markdown]
# By combining what would effectively be four individual transceivers into a single transceiver, we’re not only saving money on fiber, but we’re also saving money on the amount of equipment that we would need to support.

# %% [markdown]
# Combining the bidirectional features available in these transceivers, you can support very high speeds over a single strand of fiber optic.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Form-factor of all Transceivers
# ***

# %% [markdown]
# Here’s the form factor for all of these transceivers if we’re looking at it from the side that would plug into our networking equipment.

# %% [markdown]
# The GBIC connector that would plug into the inside of our switch and the fiber that would plug into the outside.

# %% [markdown]
# The SFP, you can see much smaller, and the quad SFP, which is really only a little bit larger than the SFP, but effectively can provide four times the functionality of the traditional SFP.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
