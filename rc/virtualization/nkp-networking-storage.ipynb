# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-infrastructure/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Storage``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Network Storage](#virtualization)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="virtualization"></a>
# ***
# ### Network Storage
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Attached Storage - NAS
# ***

# %% [markdown]
# NAS stands for Network Attached Storage.

# %% [markdown]
# This allows you to take a storage device and connect it to an Ethernet network.

# %% [markdown]
# Usually, a NAS provides file-level access - that means if you need to change just a single character inside of an entire file, need to rewrite the entire file onto that NAS device.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Storage Area Network - SAN
# ***

# %% [markdown]
# A SAN is a Storage Area Network, and this is a type of storage that is a bit more efficient than network attached storage.

# %% [markdown]
# That’s because we’re using block-level access with the SAN - this is very similar to the drive that would be in your existing computer.

# %% [markdown]
# If you need to change a single byte within a file, you only need to change that block of data - don’t have to rewrite the entire file onto that device.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### NAS versus SAN - Bandwidth
# ***

# %% [markdown]
# Regardless of whether using a NAS or a SAN, going to be sending a lot of information across the network, so you would commonly connect these to high-speed networks that can support the bandwidth required for the data that you’re transferring back and forth.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### SAN - Ethernet Frame - Jumbo Frames
# ***

# %% [markdown]
# A normal ethernet frame can support 1,500 bytes of a payload.

# %% [markdown]
# But if sending and receiving so much traffic to a storage area network, then we might want to increase the size of these frames.

# %% [markdown]
# The way to do this is to enable jumbo frames on your network - this will allow you to transfer 9,216 bytes of data within a single ethernet frame, although it’s common to configure 9,000 so it’s more compatible with the 1,500 bytes of payload.

# %% [markdown]
# Either way, you’re increasing the amount of efficiency by six times because you can fit, now, so much data within a single ethernet frame.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### SAN - Jumbo Frames - Efficiency
# ***

# %% [markdown]
# This is going to increase the efficiency of the traffic we’re sending through the network.

# %% [markdown]
# Not only is the data within the packets larger, we don’t have to make as many switching or routing decisions because we’re sending fewer packets through the network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### SAN - Jumbo Frames - Switch Configuration
# ***

# %% [markdown]
# One catch is that all of the devices on your network between you and the storage area device have to support these jumbo frames.

# %% [markdown]
# There’s usually a configuration option within your switch, and there’s usually a configuration you would set in your operating system to turn on the ability to send and receive jumbo frames.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### SAN - Fiber Channel - FC
# ***

# %% [markdown]
# One popular type of storage area network is Fiber Channel or FC.

# %% [markdown]
# This is a high-speed typology that has been specifically built for storage area networks.

# %% [markdown]
# It is built to connect servers directly to storage devices.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It can support 2, 4, 8, and 16-gigabit per second rates, and you can run this traffic over both fiber and copper connections, even though the name of it is Fiber Channel, it does support copper connectivity.

# %% [markdown]
# To use a Fiber Channel topology, you would usually have a Fiber Channel switch (see above), so you would plug-in your server with Fiber Channel, and you would plug-in your storage device with Fiber Channel.

# %% [markdown]
# The server would commonly be using some well-known protocols to communicate to those storage devices - may be using SCSI, serial attached SCSI, or SATA commands to send data over this storage area network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Fiber Channel over Ethernet - FCoE
# ***

# %% [markdown]
# There are also types of Fiber Channel networks that don’t require any specialized hardware - don’t need a Fiber Channel switch if you’re planning to use Fiber Channel over Ethernet.

# %% [markdown]
# All of these Fiber Channel commands are being sent over the existing ethernet network.

# %% [markdown]
# It’s commonly connecting over Ethernet to an existing Fiber Channel infrastructure, and since this is done at the ethernet frame level, this is not routable traffic, but this does allow you to use the ethernet card that’s in a device rather than using a Fiber Channel adapter.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Fiber Channel over IP - FCIP
# ***

# %% [markdown]
# If the storage and the devices that need access to that storage are located on different IP subnets, may want to consider using Fiber Channel over IP.

# %% [markdown]
# This is effectively tunneling Fiber Channel within existing IP packets, and that would allow you to route this traffic from one subnet to another and still be able to communicate to a Fiber Channel device.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Small Computer Systems Interface - iSCSI
# ***

# %% [markdown]
# Another type of storage area network is iSCSI - stands for Internet Small Computer Systems Interface.

# %% [markdown]
# You may be familiar with the SCSI drives that you would install with SCSI adapters inside of your computer - this simply extends that SCSI capability across the network.

# %% [markdown]
# This was created by IBM and Cisco, and it’s now an RFC standard.

# %% [markdown]
# This would make these remote drives on the storage area network look and feel as if they are local to our computer, very similar to how Fiber Channel works.

# %% [markdown]
# Of course, SCSI is well-supported in software and operating systems, and there are drivers already available for iSCSI in many existing OS’s.

# %% [markdown]
# No need any proprietary topology, there’s no need for any proprietary switches or adapter cards, and since you’re using IP, you’re using an easily routable iSCSI protocol over an existing ethernet network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### InfiniBand
# ***

# %% [markdown]
# If you need very high speeds with your storage area network, you might need InfiniBand.

# %% [markdown]
# This is a high speed storage topology that is very focused on speed, and it has its own switches and adapter cards, very similar to the way that something like Fiber Channel might be implemented.

# %% [markdown]
# With an InfiniBand, we can connect to the storage area network with both copper and fiber, using quad SFP connectors.

# %% [markdown]
# You would commonly see InfiniBand used with environments that needed very high speeds and very low latency, so for research and supercomputer operation, InfiniBnad networks are very common.

# %% [markdown]
# It’s common to see 200-gigabit per second speeds with InfiniBand networks and you can then aggregate those together in for 4x, 8x, or even 12x links.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
