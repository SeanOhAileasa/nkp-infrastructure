# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-infrastructure/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Virtual Networking``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Virtual Networking](#virtualization)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="virtualization"></a>
# ***
# ### Virtual Networking
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Virtualization
# ***

# %% [markdown]
# Virtualization has drastically changed to our modern data centers - we used to have data centers that may have 100 individual servers in them, and of course, all of those individual servers were all connected together with enterprise switches and we connected all of the separate VLANs together with enterprise routers.

# %% [markdown]
# Of course, there was redundancy, so we always had multiple switches and multiple routers to ensure there was up time to these services.

# %% [markdown]
# Then we virtualized the data center.

# %% [markdown]
# We removed those 100 physical devices and created them all virtually within one single large physical system.

# %% [markdown]
# So now that all of these servers are living in this virtual world, how do we provide switching and routing services for all of those networks and all of those VLANs?

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Hypervisor - Virtual Machine Manager
# ***

# %% [markdown]
# All of those hundreds of servers that are now virtualized will still need to be able to communicate to the physical world.

# %% [markdown]
# The component that provides this link between the virtual world and the physical world is the hypervisor.

# %% [markdown]
# You might also hear this referred to as the Virtual Machine Manager.

# %% [markdown]
# This is the component that manages the entire virtual platform for all of those virtual servers.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If you’re running a virtual machine on your existing desktop, you may want to be sure that the hypervisor is using a CPU that could support virtualization within the hardware of the CPU.

# %% [markdown]
# Intel calls this VT for Virtualization Technology.

# %% [markdown]
# AMD calls it AMDV for the Virtualization.

# %% [markdown]
# This hypervisor is the component in this virtual system that is maintaining all of these virtual CPUs to all of these devices - it's allowing you to set up separate networking components, and it can provide security for all of these virtual machines.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Requirements
# ***

# %% [markdown]
# There are a lot of different options for networking when you get into the virtual world.

# %% [markdown]
# A lot of these hypervisors will have their own internal network, so they can communicate to all of the local VMs without ever using an external network.

# %% [markdown]
# You could also use a shared address to communicate outside of the virtual machine, so there might be a single Ethernet card on this virtual machine platform and the hundreds of VMs that are inside of this device will use that single IP address associated with that interface as the connection to the outside world.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This effectively is performing a Network Address Translation (NAT) function to be able to use and share that single IP address.

# %% [markdown]
# You can also configure a virtual machine to have its own IP address rather than sharing a single natted address - this would be a bridged network address, and it will allow the VM to have its own unique addressing.

# %% [markdown]
# Some virtual machines can be configured with a private address that doesn’t communicate to anyone - this is very common to do if you’re setting up a virtual machine in a test environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Virtualization
# ***

# %% [markdown]
# But now that all of these servers have been put into a virtual environment, we can also build out switches and routers in this virtual environment as well.

# %% [markdown]
# In this scenario, I’ve got a dotted line around this virtual world that we’ve created with these hundreds of different servers inside of it.

# %% [markdown]
# Of course, there is a link to the outside world that eventually will connect to a physical switch.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Inside of this virtual world, built out a couple of virtual switches that are connecting to these virtual servers, and also got a virtual router that’s able to route between these different networks.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Because this is a virtual environment, I can make changes at any time just by making a few mouse clicks.

# %% [markdown]
# These virtual switches and virtual routers are all software that’s running in this virtual environment.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Putting in a back end process for this server that happens to have a separate database server, can simply add a different virtual switch and now got a way for this server to communicate on the back end to a separate database.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Virtualization - Virtual Firewall
# ***

# %% [markdown]
# Added virtual networking components, can also add virtual security components - could add a virtual firewall.

# %% [markdown]
# So can have a firewall protecting all of the data that’s going in and out of this virtual world.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Can also bring the security down to a port level and add multiple virtual firewalls, able to have a very specific security policy for every single link that’s going in and out of every server in this virtual environment.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# There are certainly advantages and disadvantages to all of these different configurations, but when working with a virtual environment, you have the flexibility to build the environment exactly with the resources and requirements that you need.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
