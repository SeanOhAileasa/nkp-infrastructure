# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-infrastructure/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``WAN Termination``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [WAN Termination](#wANTechnologies)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wANTechnologies"></a>
# ***
# ### WAN Termination
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Demarcation Point
# ***

# %% [markdown]
# When you’re working with a third party network provider, there needs to be some point where the hand-off is made between the provider’s network and your internal network - this is the demarcation point or the demarc.

# %% [markdown]
# It’s often a network interface on the outside of your building or it may be an interface location on the inside of your building.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We commonly have wide area network demarcs in our businesses, but we also have demarcs on the outside of our house where the phone provider or the cable company will provide that handoff point to the rest of the devices in your home.

# %% [markdown]
# In your business, there’s probably a central point in your data center where all of the demarcs from all of the providers are brought in.

# %% [markdown]
# For your home, you probably have a box on the side of the house that’s providing an RJ-11 and RJ-45 or a coax connection for your internet connectivity.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Demarcation Point - Customer Premises Equipment - CPE
# ***

# %% [markdown]
# On your side of the demarc, you connect your CPE or your customer premises equipment - may hear this abbreviated as your customer prem.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Channel Service Unit / Data Service Unit - CSU/DSU
# ***

# %% [markdown]
# If this is a traditional t1 or t3 connection, your customer premises equipment may first be a CSU/DSU.

# %% [markdown]
# This is a channel service unit/data service unit that sits between your router and the circuit that was just installed from the demarc.

# %% [markdown]
# The Channel Service Unit (CSU) part of this device connects to the network provider side.

# %% [markdown]
# The Data Service Unit (DSU) part of this device connects to your ``Data Terminal Equipment`` (DTE).

# %% [markdown]
# This is commonly a router that you might have in your environment.

# %% [markdown]
# This is commonly providing the conversion between the providers digital wide area network and a serial connection that can be understood by your router.

# %% [markdown]
# Sometimes this CSU/DSU can be an external device, but you’ll often see the CSU/DSU functionality built directly into a router.

# %% [markdown]
# So you would come directly from the demarc and connect immediately into a router where the internal DSU performs the same functions as you would have in an external device.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### CSU/DSU Connectivity
# ***

# %% [markdown]
# From the demarc we often connect with an RJ-45 light connection that’s technically an RJ-48c.

# %% [markdown]
# It might also come in and connect through a 15 pin connector to a network interface on a CSU/DSU.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# There are a number of different ways to connect between the CSU/DSU and the router, but some of the more common might use a v35 connection.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Or it might be a 25 pin serial connection between the CSU/DSU and the router.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Some CSU/DSUs also include monitor jacks that allow you to connect diagnostic equipment without disrupting the connection that’s already in place.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Smartjack - Network Interface Unit - NIU
# ***

# %% [markdown]
# Sometimes the wide area connection at the demarc is a bit more intelligent, and instead of having just a cable handoff, we would have a smart jack.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is also commonly called a network interface unit or NIU.

# %% [markdown]
# The smart jack is more than just a simple cable handoff, as you can see by these pictures.

# %% [markdown]
# These are inside the provider’s side of the communication, so you don’t usually have access to the equipment that’s inside of the smart jack.

# %% [markdown]
# The smart jack is a way for your wide area network provider to perform some additional functions.

# %% [markdown]
# For example, they could set up a loopback and provide diagnostics directly from this interface at the demarc.

# %% [markdown]
# This can also provide alarm information and reconfiguration details for the wide area network provider, so they can make a number of changes on the smart jack without having to visit your location.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
