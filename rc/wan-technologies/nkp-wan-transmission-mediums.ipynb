# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-infrastructure/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``WAN Transmission Mediums``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [WAN Transmission Mediums](#wANTechnologies)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wANTechnologies"></a>
# ***
# ### WAN Transmission Mediums
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Satellite
# ***

# %% [markdown]
# Satellite communication is communication to space - sending information to a satellite that is then directing that traffic back down to a ground station.

# %% [markdown]
# This is obviously going to be slightly more expensive than a traditional terrestrial connection but you are able to get throughputs of 50 Mbit/s down and 3 Mbits per second up.

# %% [markdown]
# You would commonly install a satellite network for your wide area network in locations that might be difficult to network or you might not have access to a cable modem or a DSL connection.

# %% [markdown]
# Given that the signal is sent up to a satellite and then back down to Earth again, will find the latencies will be much larger than what you would find for terrestrial networking.

# %% [markdown]
# Some of the best response times you might see is 250 milliseconds (ms) up and 250 ms down which is a big difference over a connection that might remain here on Earth.

# %% [markdown]
# This also commonly uses higher frequencies to communicate, usually in the 2 GHz range - this is a line of sight communication and it requires that nothing is in the way between you and the satellite.

# %% [markdown]
# It’s common when the rain clouds come in that you get rain fade.

# %% [markdown]
# The connection between you and the satellite is disrupted by all of this water that’s in between and the clouds and you have to wait for the clouds to go away to be able to receive a network communication again.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Copper
# ***

# %% [markdown]
# A large percentage of our wide area networks use copper as the communications medium - very inexpensive to install and it’s very easy to maintain.

# %% [markdown]
# Although copper is less expensive, it does come with a bandwidth limitation when you compare it to fiber.

# %% [markdown]
# But many wide area networks such as cable modems, DSL, a T1, and a T-3 all use copper for that local loop or final mile to the user.

# %% [markdown]
# For most wide area network connections it’s a combination of fiber and copper - it may be copper provided to you as the end user but there may be fiber communication within the backbone of the network provider.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Fiber
# ***

# %% [markdown]
# With fiber we’re using light to send digital signals instead of an electrical signal over copper.

# %% [markdown]
# This would have a higher installation cost than putting in a copper connection, and the equipment is certainly more costly to purchase and to maintain, but you can communicate over very long distances using fiber connectivity.

# %% [markdown]
# It’s common to see fiber used in the core of our provider networks - can put many customers over a single strand of fiber and they usually support SONET and wavelength division multiplexing using optic fiber.

# %% [markdown]
# As our bandwidth requirements have been increasing we’re starting to see more fiber make its way to the premise itself, so we’re seeing fiber installations in businesses and even fiber installations that are going through our neighborhoods and to our homes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wireless
# ***

# %% [markdown]
# There’s also wide use of wireless wide area networks - this is being used over a mobile provider’s network and we can now have our mobile phone or external hotspot provide wireless connectivity for all the devices that we happen to use every day.

# %% [markdown]
# Commonly see these wireless WAN’s used for very specific purposes such as security systems or point-of-sale reporting.

# %% [markdown]
# Also see wireless used for travel or field service operations where you don’t have a way to plug-in to a physical network connection.

# %% [markdown]
# This is, of course, limited by the coverage for that wide area network provider and there are differences in speed depending on where you may be and how far you may be away from the provider’s antenna.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
