# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-infrastructure/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``WAN Technologies``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [WAN Technologies](#wANTechnologies)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wANTechnologies"></a>
# ***
# ### WAN Technologies
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Frame Relay
# ***

# %% [markdown]
# Frame relay wide area networks became a popular typology in the 1990s.

# %% [markdown]
# It was the departure from the circuit-switched T1s to more of a packet-based communication.

# %% [markdown]
# This is where we took LAN traffic and we encapsulated within frame relay frames, and sent it into the frame relay cloud.

# %% [markdown]
# Inside of that cloud, the provider had their own method of getting the data to the other side and as the end user, never saw what that process happened to be.

# %% [markdown]
# We would simply put data into the frame relay cloud with the destination location, and the provider would take care of getting it to that remote site.

# %% [markdown]
# On the low end, it was common to see frame relay installed on 64 kbit/s, and you could have that speed range all the way up to DS3, which would be around 45 Mbit/s.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This has been effectively replaced with Multiprotocol Label Switching (MPLS) and other types of networking, but you may still see a number of frame relay implementations used on legacy networks.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Asynchronous Transfer Mode - ATM
# ***

# %% [markdown]
# ATM stands for Asynchronous Transfer Mode, and it’s a way of communicating over a SONET network.

# %% [markdown]
# ATM didn’t use frames or packets, it used 53-byte cells. Every bit of data put onto an ATM network was 53 bytes in length.

# %% [markdown]
# It was really 48-bytes for the data and 5-bytes for a header.

# %% [markdown]
# This provided high throughput, it provided real-time communication, and it had very low latency because you knew exactly when the next 53-byte cell would come through the network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The speeds of ATM had a maximum of OC-192, or about 10 gigabits per second, which at the time were extremely fast communication speeds.

# %% [markdown]
# These speeds were often limited by the segmentation and reassembly that had to occur, or the SAR.

# %% [markdown]
# That’s because our ethernet frames are much larger than the 53-byte cells.

# %% [markdown]
# We had to split our ethernet frames up into smaller pieces, put them inside of the ATM network, and then reassemble all of those frames on the other side.

# %% [markdown]
# ATM gained market share in the 1990s, but the technology faded away as IP-based technologies became more popular.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Multiprotocol Label Switching - MPLS
# ***

# %% [markdown]
# A much more modern wide area network technology is MPLS, or Multiprotocol Label Switching.

# %% [markdown]
# We looked at frame relay and ATM and took the best of both of those typologies to build MPLS.

# %% [markdown]
# In a method similar to frame relay, MPLS data is put onto the WAN with a label that designates what the destination is.

# %% [markdown]
# This makes it easy for the provider to route that traffic through the core of the network.

# %% [markdown]
# Can send many types of traffic over MPLS – they can be IP packets, we can send those older ATM cells, and we can even send ethernet frames.

# %% [markdown]
# MPLS has become a very common way of providing wide area network connectivity, and it’s easy to find services and hardware that can support an MPLS network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### MPLS - Pushing and Popping
# ***

# %% [markdown]
# One of the terms you’ll hear referenced with MPLS is ``pushing`` and ``popping``.

# %% [markdown]
# As the data is sent into the MPLS cloud, there is a label that is pushed onto packets, so that the internal provider network will know what the destination will be for that data.

# %% [markdown]
# When that data arrives on the other side, that label is popped off, and the data is provided to the customer.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Point-to-Point Protocol - PPP
# ***

# %% [markdown]
# Another popular WAN technology is PPP, or the point-to-point protocol.

# %% [markdown]
# This is a way to connect two devices so that you can then send other types of protocols over that WAN link.

# %% [markdown]
# PPP is commonly used for dial-up connections, serial links, you’ll see it for mobile phones, and it’s used for DSL connections for your home or business.

# %% [markdown]
# Some of the advantages of PPP is that it can be used for authentication of the network, data can be compressed through PPP, there’s the ability to detect errors, and you can build multiple PPP connections and multiLink those together for larger bandwidths.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Point-to-Point over Ethernet Protocol - PPPoE
# ***

# %% [markdown]
# PPPoE is an extension of PPP that encapsulates the PPP protocol within an Ethernet frame.

# %% [markdown]
# This is very common on DSL networks, and telephone providers certainly know how to use PPP, so the PPP over Ethernet is a logical extension to that.

# %% [markdown]
# It’s very easy to implement a PPP over Ethernet connection, since most operating systems already understand PPPoE.

# %% [markdown]
# There’s no complex routing decisions to make, and the architecture of PPPoE is very similar to the operation of a dial-up network.

# %% [markdown]
# PPPoE also gives you some choices in your internet provider - can use PPP over Ethernet to connect to the network, and then decide which Internet Service Provider you’d like to use at that point.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Dynamic Multipoint VPN - DMVPN - Cisco Router
# ***

# %% [markdown]
# A popular Cisco WAN technology is the DMVPN, or Dynamic Multipoint VPN.

# %% [markdown]
# It’s something you commonly find on Cisco routers because you can connect your network and have it decide when and where it would like to connect to other locations.

# %% [markdown]
# You’re effectively having all of your sites build their own VPNs as needed.

# %% [markdown]
# The tunnels are built dynamically and on-demand, depending on what location needs to speak with another location.

# %% [markdown]
# For example, it would be very common to have a main office and multiple remote sites.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Might want to connect your main office to each individual remote site.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But what if one remote site wanted to talk to another?

# %% [markdown]
# In this scenario, they would have to communicate to the main office and then back down to the remote site.

# %% [markdown]
# But with the DMVPN, those sites can dynamically build a connection between each other, send the communication they’d like to send, and then tear down the connection.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This means that any of the remote sites can send data to any of the other remote sites in the most efficient way possible.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Session Initiation Protocol - SIP Trunking
# ***

# %% [markdown]
# SIP is the Session Initiation Protocol.

# %% [markdown]
# It’s one of the more popular control protocols that are used for Voice over IP communication.

# %% [markdown]
# With a traditional business PBX, or Private Branch Exchange, you would bring in T1 lines or ISDN connections to bring in voice channels.

# %% [markdown]
# You would also have a separate wire going to every desk that would be used for the telephone that’s on everyone’s desktop.

# %% [markdown]
# When you fill up all of those 23 voice channels, people calling in would get a busy signal.

# %% [markdown]
# With SIP trunking, you’re using a Voice over IP connection to an IP or PBX provider that allows you to communicate using Voice over IP.

# %% [markdown]
# This is a much more efficient use of bandwidth – then you can control just how much compression you’re using on these Voice over IP calls, so you’re able to support much more capacity than a traditional ISDN or T1 connection.

# %% [markdown]
# It’s less expensive than ISDN lines, and you have many more options available on your digital Voice over IP communication.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
